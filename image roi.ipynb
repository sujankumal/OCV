# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img =  cv2.imread('football.png')

# %%
img.shape
# Out:
# (401, 643, 3)

# %%
ball = img[340:400, 400:460]

# %%
img[340:400, 50:110] = ball

# %%
plt.imshow(img)
plt.show()

# %%
cv2.namedWindow('Image', cv2.WINDOW_NORMAL)
cv2.imshow('Image', img)

# %%
cv2.destroyAllWindows()
