# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     West Bank and Gaza Country Code                Indicator Name  \
# 0                Aruba          ABW  GDP per capita (current US$)
# 1          Afghanistan          AFG  GDP per capita (current US$)
# 2               Angola          AGO  GDP per capita (current US$)
# 3              Albania          ALB  GDP per capita (current US$)
# 4              Andorra          AND  GDP per capita (current US$)
# ..                 ...          ...                           ...
# 259             Kosovo          XKX  GDP per capita (current US$)
# 260        Yemen, Rep.          YEM  GDP per capita (current US$)
# 261       South Africa          ZAF  GDP per capita (current US$)
# 262             Zambia          ZMB  GDP per capita (current US$)
# 263           Zimbabwe          ZWE  GDP per capita (current US$)
#
#      Indicator Code        1960        1961        1962        1963  \
# 0    NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# ...

# %%
df1 = pd.Series()
# Out:
#     West Bank and Gaza Country Code                Indicator Name  \
# 0                Aruba          ABW  GDP per capita (current US$)
# 1          Afghanistan          AFG  GDP per capita (current US$)
# 2               Angola          AGO  GDP per capita (current US$)
# 3              Albania          ALB  GDP per capita (current US$)
# 4              Andorra          AND  GDP per capita (current US$)
# ..                 ...          ...                           ...
# 259             Kosovo          XKX  GDP per capita (current US$)
# 260        Yemen, Rep.          YEM  GDP per capita (current US$)
# 261       South Africa          ZAF  GDP per capita (current US$)
# 262             Zambia          ZMB  GDP per capita (current US$)
# 263           Zimbabwe          ZWE  GDP per capita (current US$)
#
#      Indicator Code        1960        1961        1962        1963  \
# 0    NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# ...

# %%
df1 = pd.DataFrame([df['West Bank and Gaza'], x:x df['1960'] ])

# %%
df1
# Out:
#                       0            1       2        3        4           5    \
# West Bank and Gaza  Aruba  Afghanistan  Angola  Albania  Andorra  Arab World
#
#                                      6          7        8               9    \
# West Bank and Gaza  United Arab Emirates  Argentina  Armenia  American Samoa
#
#                     ...                    254      255      256    257  \
# West Bank and Gaza  ...  Virgin Islands (U.S.)  Vietnam  Vanuatu  World
#
#                       258     259          260           261     262       263
# West Bank and Gaza  Samoa  Kosovo  Yemen, Rep.  South Africa  Zambia  Zimbabwe
#
# [1 rows x 264 columns]
