# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('football.png',1)
cv2.namedWindow('Image', cv2.WINDOW_NORMAL)
cv2.imshow('Image', img)

# %%
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
b,g,r = cv2.split(img)

# Warning: cv2.split() is a costly operation (in terms of time), so only use it if necessary. Numpy indexing
# is much more efficient and should be used if possible.

# %%
b
# Out:
# array([[55, 55, 55, ..., 53, 57, 61],
#        [59, 59, 58, ..., 54, 57, 61],
#        [61, 61, 60, ..., 56, 59, 62],
#        ...,
#        [54, 49, 49, ..., 53, 46, 43],
#        [50, 47, 48, ..., 51, 46, 44],
#        [55, 54, 56, ..., 52, 50, 51]], dtype=uint8)

# %%
b.shape
# Out:
# (401, 643)

# %%
g
# Out:
# array([[ 60,  60,  59, ...,  52,  56,  60],
#        [ 63,  63,  63, ...,  53,  57,  61],
#        [ 67,  67,  65, ...,  54,  58,  62],
#        ...,
#        [138, 132, 131, ..., 129, 122, 119],
#        [135, 130, 130, ..., 127, 122, 119],
#        [137, 135, 136, ..., 128, 126, 126]], dtype=uint8)

# %%
plt.subplot(131)
plt.imshow(b)
plt.subplot(132)
plt.imshow(g)
plt.subplot(133)
plt.imshow(r)

# %%
plt.imshow(img)
plt.show()

# %%
img1 = cv2.merge((b,g,r))
plt.imshow(img1)
plt.show()

# %%
b = img1[:,:,0]

# %%
img1[:,:,1]=0

# %%
plt.imshow(img1)
